# %%
# !pip install ctab-xtra-dp==3.6.0
# Out:
# Collecting ctab-xtra-dp==3.6.0
#   Downloading ctab_xtra_dp-3.6.0-py3-none-any.whl.metadata (15 kB)
# Requirement already satisfied: pandas in c:\users\marti\appdata\local\programs\python\python312\lib\site-packages (from ctab-xtra-dp==3.6.0) (2.2.3)
# Requirement already satisfied: numpy in c:\users\marti\appdata\local\programs\python\python312\lib\site-packages (from ctab-xtra-dp==3.6.0) (2.1.3)
# Requirement already satisfied: matplotlib in c:\users\marti\appdata\local\programs\python\python312\lib\site-packages (from ctab-xtra-dp==3.6.0) (3.10.0)
# Requirement already satisfied: seaborn in c:\users\marti\appdata\local\programs\python\python312\lib\site-packages (from ctab-xtra-dp==3.6.0) (0.13.2)
# Requirement already satisfied: scikit-learn in c:\users\marti\appdata\local\programs\python\python312\lib\site-packages (from ctab-xtra-dp==3.6.0) (1.6.1)
# Requirement already satisfied: torch in c:\users\marti\appdata\local\programs\python\python312\lib\site-packages (from ctab-xtra-dp==3.6.0) (2.5.1)
# Requirement already satisfied: tqdm in c:\users\marti\appdata\local\programs\python\python312\lib\site-packages (from ctab-xtra-dp==3.6.0) (4.67.1)
# Requirement already satisfied: dython in c:\users\marti\appdata\local\programs\python\python312\lib\site-packages (from ctab-xtra-dp==3.6.0) (0.7.9)
# Requirement already satisfied: pathlib in c:\users\marti\appdata\local\programs\python\python312\lib\site-packages (from ctab-xtra-dp==3.6.0) (1.0.1)
# Requirement already satisfied: xgboost in c:\users\marti\appdata\local\programs\python\python312\lib\site-packages (from ctab-xtra-dp==3.6.0) (3.0.0)
# Requirement already satisfied: catboost in c:\users\marti\appdata\local\programs\python\python312\lib\site-packages (from ctab-xtra-dp==3.6.0) (1.2.8)
# Requirement already satisfied: lightgbm in c:\users\marti\appdata\local\programs\python\python312\lib\site-packages (from ctab-xtra-dp==3.6.0) (4.6.0)
# Requirement already satisfied: graphviz in c:\users\marti\appdata\local\programs\python\python312\lib\site-packages (from catboost->ctab-xtra-dp==3.6.0) (0.20.3)
# Requirement already satisfied: scipy in c:\users\marti\appdata\local\programs\python\python312\lib\site-packages (from catboost->ctab-xtra-dp==3.6.0) (1.15.1)
# Requirement already satisfied: plotly in c:\users\marti\appdata\local\programs\python\python312\lib\site-packages (from catboost->ctab-xtra-dp==3.6.0) (6.0.1)
# Requirement already satisfied: six in c:\users\marti\appdata\roaming\python\python312\site-packages (from catboost->ctab-xtra-dp==3.6.0) (1.17.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\marti\appdata\roaming\python\python312\site-packages (from pandas->ctab-xtra-dp==3.6.0) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\marti\appdata\local\programs\python\python312\lib\site-packages (from pandas->ctab-xtra-dp==3.6.0) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\marti\appdata\local\programs\python\python312\lib\site-packages (from pandas->ctab-xtra-dp==3.6.0) (2025.1)
# Requirement already satisfied: psutil>=5.9.1 in c:\users\marti\appdata\roaming\python\python312\site-packages (from dython->ctab-xtra-dp==3.6.0) (6.1.1)
# Requirement already satisfied: setuptools in c:\users\marti\appdata\local\programs\python\python312\lib\site-packages (from dython->ctab-xtra-dp==3.6.0) (75.8.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\marti\appdata\local\programs\python\python312\lib\site-packages (from matplotlib->ctab-xtra-dp==3.6.0) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\marti\appdata\local\programs\python\python312\lib\site-packages (from matplotlib->ctab-xtra-dp==3.6.0) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\marti\appdata\local\programs\python\python312\lib\site-packages (from matplotlib->ctab-xtra-dp==3.6.0) (4.55.4)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\marti\appdata\local\programs\python\python312\lib\site-packages (from matplotlib->ctab-xtra-dp==3.6.0) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in c:\users\marti\appdata\roaming\python\python312\site-packages (from matplotlib->ctab-xtra-dp==3.6.0) (24.2)
# Requirement already satisfied: pillow>=8 in c:\users\marti\appdata\local\programs\python\python312\lib\site-packages (from matplotlib->ctab-xtra-dp==3.6.0) (11.1.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\marti\appdata\local\programs\python\python312\lib\site-packages (from matplotlib->ctab-xtra-dp==3.6.0) (3.2.1)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\marti\appdata\local\programs\python\python312\lib\site-packages (from scikit-learn->ctab-xtra-dp==3.6.0) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\marti\appdata\local\programs\python\python312\lib\site-packages (from scikit-learn->ctab-xtra-dp==3.6.0) (3.5.0)
# Requirement already satisfied: narwhals>=1.15.1 in c:\users\marti\appdata\local\programs\python\python312\lib\site-packages (from plotly->catboost->ctab-xtra-dp==3.6.0) (1.36.0)
# Requirement already satisfied: filelock in c:\users\marti\appdata\local\programs\python\python312\lib\site-packages (from torch->ctab-xtra-dp==3.6.0) (3.17.0)
# Requirement already satisfied: typing-extensions>=4.8.0 in c:\users\marti\appdata\local\programs\python\python312\lib\site-packages (from torch->ctab-xtra-dp==3.6.0) (4.12.2)
# Requirement already satisfied: networkx in c:\users\marti\appdata\local\programs\python\python312\lib\site-packages (from torch->ctab-xtra-dp==3.6.0) (3.4.2)
# Requirement already satisfied: jinja2 in c:\users\marti\appdata\local\programs\python\python312\lib\site-packages (from torch->ctab-xtra-dp==3.6.0) (3.1.5)
# Requirement already satisfied: fsspec in c:\users\marti\appdata\local\programs\python\python312\lib\site-packages (from torch->ctab-xtra-dp==3.6.0) (2024.12.0)
# Requirement already satisfied: sympy==1.13.1 in c:\users\marti\appdata\local\programs\python\python312\lib\site-packages (from torch->ctab-xtra-dp==3.6.0) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\marti\appdata\local\programs\python\python312\lib\site-packages (from sympy==1.13.1->torch->ctab-xtra-dp==3.6.0) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\marti\appdata\local\programs\python\python312\lib\site-packages (from jinja2->torch->ctab-xtra-dp==3.6.0) (3.0.2)
# Requirement already satisfied: colorama in c:\users\marti\appdata\roaming\python\python312\site-packages (from tqdm->ctab-xtra-dp==3.6.0) (0.4.6)
# Downloading ctab_xtra_dp-3.6.0-py3-none-any.whl (1.3 MB)
#    ---------------------------------------- 0.0/1.3 MB ? eta -:--:--
#    ---------------------------------------- 1.3/1.3 MB 8.0 MB/s eta 0:00:00
# Installing collected packages: ctab-xtra-dp
#   Attempting uninstall: ctab-xtra-dp
#     Found existing installation: ctab_xtra_dp 3.5.0
#     Uninstalling ctab_xtra_dp-3.5.0:
#       Successfully uninstalled ctab_xtra_dp-3.5.0
# Successfully installed ctab-xtra-dp-3.6.0
# WARNING: Ignoring invalid distribution ~ (C:\Users\marti\AppData\Local\Programs\Python\Python312\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~tab-xtra-dp (C:\Users\marti\AppData\Local\Programs\Python\Python312\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~ (C:\Users\marti\AppData\Local\Programs\Python\Python312\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~tab-xtra-dp (C:\Users\marti\AppData\Local\Programs\Python\Python312\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~ (C:\Users\marti\AppData\Local\Programs\Python\Python312\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~tab-xtra-dp (C:\Users\marti\AppData\Local\Programs\Python\Python312\Lib\site-packages)

# %%
import pandas as pd
import numpy as np 
from ctab_xtra_dp import evaluation

# %%
real = pd.read_csv('../datasets/Adult.csv')

categorical_columns = ['workclass', 'education', 'marital-status', 'occupation', 
                         'relationship', 'race', 'gender', 'native-country','income']

train, test = evaluation.split_data(real, 0.2, "income",random_state=22)

fakes = [
    '../data_generation/synthetic_data/adult_target_epochs_100_epsilon_None.csv',
    '../data_generation/synthetic_data/adult_target_epochs_100_epsilon_15.csv',
    '../data_generation/synthetic_data/adult_target_epochs_100_epsilon_5.csv',
    '../data_generation/synthetic_data/adult_target_epochs_100_epsilon_1.csv',
]


for fake_path in fakes:
    fake = pd.read_csv(fake_path)
    print(f'Fake data: {fake_path}')
    evaluation.privacy_metrics(train,fake,data_percent=0.01,verbose=True)

# %%
real = pd.read_csv('../datasets/king.csv')

categorical_columns = ['bedrooms', "floors", 'waterfront', 'view', 'condition', 'grade','zipcode']

train, test = evaluation.split_data(real, 0.2, "price",random_state=22,problem='regression')

fakes = [
    '../data_generation/synthetic_data/king_epochs_100_epsilon_None.csv',
    '../data_generation/synthetic_data/king_epochs_100_epsilon_15.csv',
    '../data_generation/synthetic_data/king_epochs_100_epsilon_5.csv',
    '../data_generation/synthetic_data/king_epochs_100_epsilon_1.csv',
]


for fake_path in fakes:
    fake = pd.read_csv(fake_path)
    print(f'Fake data: {fake_path}')
    evaluation.privacy_metrics(train,fake,data_percent=0.01,verbose=True)
# Out:
# Fake data: ../data_generation/synthetic_data/king_epochs_100_epsilon_None.csv
# ==== Privacy Metrics Analysis ====
# Using 0.01% of data for analysis
# Real data sample size: 172
# Fake data sample size: 172
#
# Calculating pairwise distances...
#
# == Nearest Neighbor Ratio Metrics (5th percentile) ==
# Real-to-Real NN Ratio (5th): 0.6014
# Fake-to-Fake NN Ratio (5th): 0.6799
# Real-to-Fake NN Ratio (5th): 0.6153
#
# == Minimum Distance Metrics (5th percentile) ==
# Real-to-Real Min Distance (5th): 0.0317
# Fake-to-Fake Min Distance (5th): 0.0462
# Real-to-Fake Min Distance (5th): 0.0341
#
# == Nearest Neighbor Adversarial Accuracy (NNAA) ==
# NNAA: 0.4012
#
# ==== Summary Interpretation ====
# ⚠ Synthetic records may be too similar to real data
# ⚠ Neighbor distance ratios indicate possible privacy concerns
# Fake data: ../data_generation/synthetic_data/king_epochs_100_epsilon_15.csv
# ==== Privacy Metrics Analysis ====
# Using 0.01% of data for analysis
# Real data sample size: 172
# Fake data sample size: 172
#
# Calculating pairwise distances...
#
# == Nearest Neighbor Ratio Metrics (5th percentile) ==
# Real-to-Real NN Ratio (5th): 0.6014
# Fake-to-Fake NN Ratio (5th): 0.7024
# Real-to-Fake NN Ratio (5th): 0.6582
#
# == Minimum Distance Metrics (5th percentile) ==
# Real-to-Real Min Distance (5th): 0.0317
# Fake-to-Fake Min Distance (5th): 0.0634
# Real-to-Fake Min Distance (5th): 0.0476
#
# == Nearest Neighbor Adversarial Accuracy (NNAA) ==
# NNAA: 0.6279
#
# ==== Summary Interpretation ====
# ✓ Good distance between real and synthetic records
# ✓ Good neighbor distance ratios
# Fake data: ../data_generation/synthetic_data/king_epochs_100_epsilon_5.csv
# ==== Privacy Metrics Analysis ====
# Using 0.01% of data for analysis
# Real data sample size: 172
# Fake data sample size: 172
#
# Calculating pairwise distances...
#
# == Nearest Neighbor Ratio Metrics (5th percentile) ==
# Real-to-Real NN Ratio (5th): 0.6014
# Fake-to-Fake NN Ratio (5th): 0.6987
# Real-to-Fake NN Ratio (5th): 0.7172
#
# == Minimum Distance Metrics (5th percentile) ==
# Real-to-Real Min Distance (5th): 0.0317
# Fake-to-Fake Min Distance (5th): 0.0508
# Real-to-Fake Min Distance (5th): 0.0435
#
# == Nearest Neighbor Adversarial Accuracy (NNAA) ==
# NNAA: 0.5610
#
# ==== Summary Interpretation ====
# ✓ Good distance between real and synthetic records
# ✓ Good neighbor distance ratios
# Fake data: ../data_generation/synthetic_data/king_epochs_100_epsilon_1.csv
# ==== Privacy Metrics Analysis ====
# Using 0.01% of data for analysis
# Real data sample size: 172
# Fake data sample size: 172
#
# Calculating pairwise distances...
#
# == Nearest Neighbor Ratio Metrics (5th percentile) ==
# Real-to-Real NN Ratio (5th): 0.6014
# Fake-to-Fake NN Ratio (5th): 0.5975
# Real-to-Fake NN Ratio (5th): 0.6672
#
# == Minimum Distance Metrics (5th percentile) ==
# Real-to-Real Min Distance (5th): 0.0317
# Fake-to-Fake Min Distance (5th): 0.0454
# Real-to-Fake Min Distance (5th): 0.0443
#
# == Nearest Neighbor Adversarial Accuracy (NNAA) ==
# NNAA: 0.5785
#
# ==== Summary Interpretation ====
# ✓ Good distance between real and synthetic records
# ✓ Good neighbor distance ratios

# %%
real = pd.read_csv('../datasets/fraud.csv')

categorical_columns =  ["fraud_bool","payment_type","employment_status","email_is_free","housing_status","device_os","phone_home_valid","has_other_cards","keep_alive_session"]

train, test = evaluation.split_data(real, 0.2, "fraud_bool",random_state=22)

fakes = [
    '../data_generation/synthetic_data/fraud_epochs_100_epsilon_None.csv',
    '../data_generation/synthetic_data/fraud_epochs_100_epsilon_15.csv',
    '../data_generation/synthetic_data/fraud_epochs_100_epsilon_5.csv',
    '../data_generation/synthetic_data/fraud_epochs_100_epsilon_1.csv',
]

missing_values_columns = ["prev_address_months_count", "current_address_months_count", "device_distinct_emails_8w"]

for fake_path in fakes:
    fake = pd.read_csv(fake_path)
    fake[missing_values_columns] = fake[missing_values_columns].replace(-1, np.nan)
    print(f'Fake data: {fake_path}')
    evaluation.privacy_metrics(train,fake,data_percent=0.01,verbose=True)
# Out:
# Fake data: ../data_generation/synthetic_data/king_epochs_100_epsilon_None.csv
# ==== Privacy Metrics Analysis ====
# Using 0.01% of data for analysis
# Real data sample size: 400
# Fake data sample size: 172
#
# Calculating pairwise distances...
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[32], line 19
#      17 fake = pd.read_csv(fake_path)
#      18 print(f'Fake data: {fake_path}')
# ---> 19 evaluation.privacy_metrics(train,fake,data_percent=0.01,verbose=True)
#
# File c:\Users\marti\AppData\Local\Programs\Python\Python312\Lib\site-packages\ctab_xtra_dp\model\evaluation\evaluation.py:501, in privacy_metrics(real, fake, metric, data_percent, verbose)
#     498   print("\nCalculating pairwise distances...")
#     500 # Compute distance matrix from real-fake, real-real, and fake-fake
# --> 501 dist_rf, dist_rr, dist_ff = _calculate_pariwise_distances(real_refined, fake_refined, metric=metric)
#     503 # Remove the diagonal to ignore self-distances
#     504 dist_rr = dist_rr[~np.eye(dist_rr.shape[0],dtype=bool)].reshape(dist_rr.shape[0],-1)
#
# File c:\Users\marti\AppData\Local\Programs\Python\Python312\Lib\site-packages\ctab_xtra_dp\model\evaluation\evaluation.py:612, in _calculate_pariwise_distances(real, fake, metric)
#     610 dist_ff = 0 # Pairwise distance between fake and fake
#     611 if metric == 'gower':
# --> 612   dist_rf = gower_distance(real,fake)
#     613   dist_rr = gower_distance(real,real)
#     614   dist_ff = gower_distance(fake,fake)
#
# File c:\Users\marti\AppData\Local\Programs\Python\Python312\Lib\site-packages\ctab_xtra_dp\model\evaluation\gower_mix.py:21, in gower_distance(data_x, data_y, weight, mix_features)
#      18 if not isinstance(Y, np.ndarray): Y = np.asarray(Y)
#      20 if X.shape[1] != Y.shape[1]:
# ---> 21     raise ValueError(f"X and Y must have the same number of columns")
#      22 n_cols = X.shape[1] # the number of columns for both X and Y
#      24 # Set default weights if not provided
#
# ValueError: X and Y must have the same number of columns
